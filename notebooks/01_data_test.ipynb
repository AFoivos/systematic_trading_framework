# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve().parents[0]
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

print("PROJECT_ROOT:", PROJECT_ROOT)
# Out:
# PROJECT_ROOT: /workspaces/systematic-trading-framework

# %%
from src.data.loaders import load_ohlcv

# %%
df = load_ohlcv(
    symbol="SPY",
    start="2018-01-01",
    interval="1d",
)
df.head()
# Out:
# Price             open        high         low       close    volume
# Date
# 2018-01-02  267.839996  268.809998  267.399994  268.769989  86655700
# 2018-01-03  268.959991  270.640015  268.959991  270.470001  90070400
# 2018-01-04  271.200012  272.160004  270.540009  271.609985  80636400
# 2018-01-05  272.510010  273.559998  271.950012  273.420013  83524000
# 2018-01-08  273.309998  274.100006  272.980011  273.920013  57319200

# %%
from src.data.validation import validate_ohlcv

# %%
validate_ohlcv(df)

# %%
df.head()
# Out:
# Price             open        high         low       close    volume
# Date
# 2018-01-02  267.839996  268.809998  267.399994  268.769989  86655700
# 2018-01-03  268.959991  270.640015  268.959991  270.470001  90070400
# 2018-01-04  271.200012  272.160004  270.540009  271.609985  80636400
# 2018-01-05  272.510010  273.559998  271.950012  273.420013  83524000
# 2018-01-08  273.309998  274.100006  272.980011  273.920013  57319200

# %%
from src.features.returns import add_close_returns

# %%
df = add_close_returns(df, log=True)

# %%
df[["close", "close_logret"]].head()
# Out:
# Price            close  close_logret
# Date
# 2018-01-02  268.769989           NaN
# 2018-01-03  270.470001      0.006305
# 2018-01-04  271.609985      0.004206
# 2018-01-05  273.420013      0.006642
# 2018-01-08  273.920013      0.001827

# %%
df[["close"]].describe().plot(kind="bar")
# Out:
# <Axes: >
